# %% [markdown]
# - **Install required dependencies**

# %%
# %pip install langchain langgraph langgraph-supervisor langgraph-swarm crewai
# Out:
# ...
#   Using cached tomli-2.2.1-py3-none-any.whl.metadata (10 kB)
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 292.0 kB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 571.1 kB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.9/18.9 MB 528.5 kB/s eta 0:00:0000:0100:02
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 647.0/647.0 kB 211.0 kB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 482.5 kB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 756.0/756.0 kB 389.7 kB/s eta 0:00:00a 0:00:01
# Using cached tomli-2.2.1-py3-none-any.whl (14 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 378.5 kB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 401.3 kB/s eta 0:00:00a 0:00:01
# ...

# %%
# %pip install langchain_openai
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install langchain-mcp-adapters
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# - test mcp server request

# %%
import requests
import json
from pprint import pprint
pprint(requests.get('http://localhost:9090/mcp', headers={'mcp-session-id':'1868a90c121','Accept':'text/event-stream'}).text)
# Out:
# 'Bad Request: No valid session ID provided'
